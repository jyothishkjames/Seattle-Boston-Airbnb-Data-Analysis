# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

seattle_calander_df = pd.read_csv('./dataset/seattle/calendar.csv', dtype=str)
seattle_listings_df = pd.read_csv('./dataset/seattle/listings.csv', dtype=str)
seattle_reviews_df = pd.read_csv('./dataset/seattle/reviews.csv', dtype=str)

print(seattle_calander_df.shape)
print(seattle_listings_df.shape)
print(seattle_reviews_df.shape)

seattle_calander_df.head()
# Out:
# (1393570, 4)
# (3818, 92)
# (84849, 6)
#   listing_id        date available   price
# 0     241032  2016-01-04         t  $85.00
# 1     241032  2016-01-05         t  $85.00
# 2     241032  2016-01-06         f     NaN
# 3     241032  2016-01-07         f     NaN
# 4     241032  2016-01-08         f     NaN

# %%
seattle_listings_df.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
# 3  A charming apartment that sits atop Queen Anne...                none
# 4  Cozy family craftman house in beautiful neighb...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0                                                NaN  ...                  10
# 1  Queen Anne is a wonderful, truly functional vi...  ...                  10
# 2  Upper Queen Anne is a charming neighborhood fu...  ...                  10
# 3                                                NaN  ...                 NaN
# 4  We are in the beautiful neighborhood of Queen ...  ...                   9
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN         WASHINGTON                f
# 1                f     NaN         WASHINGTON                f
# 2                f     NaN         WASHINGTON                f
# 3                f     NaN         WASHINGTON                f
# 4                f     NaN         WASHINGTON                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1              strict                             t
# 2              strict                             f
# 3            flexible                             f
# 4              strict                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              2
# 1                                t                              6
# 2                                f                              2
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              4.07
# 1              1.48
# 2              1.15
# 3               NaN
# 4              0.89
#
# [5 rows x 92 columns]

# %%
seattle_reviews_df.head()
# Out:
#   listing_id        id        date reviewer_id reviewer_name  \
# 0    7202016  38917982  2015-07-19    28943674        Bianca
# 1    7202016  39087409  2015-07-20    32440555         Frank
# 2    7202016  39820030  2015-07-26    37722850           Ian
# 3    7202016  40813543  2015-08-02    33671805        George
# 4    7202016  41986501  2015-08-10    34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
boston_calander_df = pd.read_csv('./dataset/boston/calendar.csv', dtype=str)
boston_listings_df = pd.read_csv('./dataset/boston/listings.csv', dtype=str)
boston_reviews_df = pd.read_csv('./dataset/boston/reviews.csv', dtype=str)

print(boston_calander_df.shape)
print(boston_listings_df.shape)
print(boston_reviews_df.shape)
# Out:
# (1308890, 4)
# (3585, 95)
# (68275, 6)

# %%
boston_listings_df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
# 1  The room is in Roslindale, a diverse and prima...  ...                   9
# 2  The LOCATION: Roslindale is a safe and diverse...  ...                  10
# 3  Roslindale is a lovely little neighborhood loc...  ...                  10
# 4  I love the proximity to downtown, the neighbor...  ...                  10
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                t
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0               NaN
# 1              1.30
# 2              0.47
# 3                 1
# 4              2.25
#
# [5 rows x 95 columns]

# %%
boston_reviews_df.head()
# Out:
#   listing_id       id        date reviewer_id reviewer_name  \
# 0    1178162  4724140  2013-05-21     4298113       Olivier
# 1    1178162  4869189  2013-05-29     6452964     Charlotte
# 2    1178162  5003196  2013-06-06     6449554     Sebastian
# 3    1178162  5150351  2013-06-15     2215611        Marine
# 4    1178162  5171140  2013-06-16     6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
    # Questions to ask:
    # * Planned visitors to Seattle/Boston over time (based on non availability of listings)?
    #  - date, accommodates (columns)
    # * Which areas are more crowded, which areas are more preferred by people?
    #  - neighbourhood, street, zipcode (columns)
    # * Busiest time to visit Seattle/Boston?
    #  - date, accommodates (columns) : Seattle-July, Boston-March.
    # * Compare the average daily price for a month over time(between the two cities).
    #  - price, date, weekly_price, monthly_price (columns) from calendar.csv
    # * Predict price.
    #  - property_type, room_type, neighbourhood, zipcode, accommodates, transit
    #  bathrooms, bedrooms, beds, cleaning fee, reviews, instant_bookable (plot corelation matrix)
    #  cancellation_policy (columns or more)

# %%
def clean_data():
    
    """filling missing values for the field 'price' in dataframes 
    'seattle_calander_df' and 'boston_calander_df'"""
    seattle_calander_df['price'].fillna(method='ffill', inplace=True)
    boston_calander_df['price'].fillna(method='bfill', inplace=True)
    boston_calander_df['price'].fillna(method='ffill', inplace=True) 
    
    """filling missing values for the field 'neighbourhood' and 'zipcode'
    in dataframes 'seattle_listings_df' and 'boston_listings_df'"""
    seattle_listings_df['neighbourhood'].fillna(method='ffill', inplace=True) 
    seattle_listings_df['zipcode'].fillna(method='ffill', inplace=True) 
    boston_listings_df['neighbourhood'].fillna(method='ffill', inplace=True) 
    boston_listings_df['zipcode'].fillna(method='ffill', inplace=True) 
   
    """Removing '$' and ',' symbol from price in dataframes 
    'seattle_calander_df' and 'boston_calander_df'"""
    seattle_calander_df['price'] = seattle_calander_df['price'].str.replace('$', '')
    seattle_calander_df['price'] = seattle_calander_df['price'].str.replace(',', '')
    boston_calander_df['price'] = boston_calander_df['price'].str.replace('$', '')
    boston_calander_df['price'] = boston_calander_df['price'].str.replace(',', '')
    
    """Removing '$' and ',' symbol from price in dataframes
    'seattle_listings_df' and 'boston_listings_df'"""
    seattle_listings_df['price'] = seattle_listings_df['price'].str.replace('$', '')
    seattle_listings_df['price'] = seattle_listings_df['price'].str.replace(',', '')
    boston_listings_df['price'] = boston_listings_df['price'].str.replace('$', '')
    boston_listings_df['price'] = boston_listings_df['price'].str.replace(',', '')
    
    """convert 'price', 'accommodates' columns in dataframes 'seattle_calander_df', 
    'seattle_calander_df', 'boston_calander_df' and 'boston_calander_df' to float type""" 
    seattle_calander_df["price"] = pd.to_numeric(seattle_calander_df["price"])
    seattle_listings_df["price"] = pd.to_numeric(seattle_listings_df["price"])
    seattle_listings_df["accommodates"] = pd.to_numeric(seattle_listings_df["accommodates"])
    boston_calander_df["price"] = pd.to_numeric(boston_calander_df["price"])
    boston_listings_df["price"] = pd.to_numeric(boston_listings_df["price"])
    boston_listings_df["accommodates"] = pd.to_numeric(boston_listings_df["accommodates"])
    
    """Renaming column 'id' to 'listing_id' in dataframes 'seattle_listings_df'
    and 'boston_calander_df'""" 
    seattle_listings_df.rename(columns={"id": "listing_id"}, inplace=True)
    boston_listings_df.rename(columns={"id": "listing_id"}, inplace=True)

    
def add_columns():
    
    """adding columns for month and year in dataframes 'seattle_calander_df'
    and 'boston_calander_df'"""
    func_month = lambda x: x.split('-')[1] 
    func_year = lambda x: x.split('-')[0] 

    seattle_calander_df['month'] = pd.to_numeric(seattle_calander_df['date'].apply(func_month))
    seattle_calander_df['year'] = pd.to_numeric(seattle_calander_df['date'].apply(func_year))

    boston_calander_df['month'] = pd.to_numeric(boston_calander_df['date'].apply(func_month))
    boston_calander_df['year'] = pd.to_numeric(boston_calander_df['date'].apply(func_year))

clean_data()   
add_columns()

# %%
#Compare the average daily price for a month over time(between the two cities).
#-------------------------------------------------------

"""check if there are any NaN values in the column 'price' in dataframes 
'seattle_calander_df' and 'boston_calander_df'"""
seattle_calander_df[seattle_calander_df['price'].isna() == True]
boston_calander_df[boston_calander_df['price'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [listing_id, date, available, price, month, year]
# Index: []

# %%
seattle_calander_df.head()
# Out:
#   listing_id        date available  price  month  year
# 0     241032  2016-01-04         t   85.0      1  2016
# 1     241032  2016-01-05         t   85.0      1  2016
# 2     241032  2016-01-06         f   85.0      1  2016
# 3     241032  2016-01-07         f   85.0      1  2016
# 4     241032  2016-01-08         f   85.0      1  2016

# %%
#Selecting only the year 2016
seattle_calander_df = seattle_calander_df[seattle_calander_df['year'] == 2016]
boston_calander_df = boston_calander_df[boston_calander_df['year'] == 2017]

# %%
boston_calander_df.head()
# Out:
#   listing_id        date available  price  month  year
# 0   12147973  2017-09-05         f   65.0      9  2017
# 1   12147973  2017-09-04         f   65.0      9  2017
# 2   12147973  2017-09-03         f   65.0      9  2017
# 3   12147973  2017-09-02         f   65.0      9  2017
# 4   12147973  2017-09-01         f   65.0      9  2017

# %%
#Line plot for the average daily price for a month over a year for Seattle
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.set_title('Seattle: Price vs Month')
ax.set_xlabel('Month')
ax.set_ylabel('Price')

seattle_calander_df.groupby('month')['price'].mean().plot(kind='line', color='blue', ax=ax)

# %%
#Line plot for the average daily price for a month over a year for Boston
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.set_title('Boston: Price vs Month')
ax.set_xlabel('Month')
ax.set_ylabel('Price')
boston_calander_df.groupby('month')['price'].mean().plot(kind='line', color='red', ax=ax)

# %%
# Planned visitors to Seattle/Boston over time (based on non availability of listings)?
#----------------------------------------------------------------------------------------

"""Find the rows which has 'availability' column as 'f'"""
seattle_booked_df =  seattle_calander_df[seattle_calander_df['available'] == 'f']
boston_booked_df =  boston_calander_df[boston_calander_df['available'] == 'f']

# %%
"""Merge dataframes 'df_seattle_booked' and 'seattle_listings_df'"""
seattle_merged_df = pd.merge(seattle_booked_df, seattle_listings_df, on=['listing_id'])

"""Merge dataframes 'df_boston_booked' and 'seattle_listings_df'"""
boston_merged_df = pd.merge(boston_booked_df, boston_listings_df, on=['listing_id'])

# %%
#Line plot for predicted visitors to Seattle over time
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.set_title('Seattle: Number of visitors vs Month')
ax.set_xlabel('Month')
ax.set_ylabel('Number of visitors')
seattle_merged_df.groupby('month')['accommodates'].sum().plot(kind='line', color='red', ax=ax)

# %%
#Line plot for predicted visitors to Boston over time
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.set_title('Boston: Number of visitors vs Month')
ax.set_xlabel('Month')
ax.set_ylabel('Number of visitors')
boston_merged_df.groupby('month')['accommodates'].sum().plot(kind='line', color='blue', ax=ax)

# %%
# Which areas are more crowded, which areas are more preferred by people?

# Group streets by neighborhood - boston_listings_df
boston_listings_df[['neighbourhood','street']].groupby('neighbourhood')['street'].describe()
# Out:
#                    count unique  \
# neighbourhood
# Allston-Brighton     425    164
# Back Bay             332     64
# Beacon Hill          211     54
# Brookline             15     13
# Cambridge              8      8
# Charlestown           90     57
# Chestnut Hill          4      3
# Chinatown             87     19
# Dorchester           263    128
# Downtown              11      8
# Downtown Crossing     30     13
# East Boston          149     49
# Fenway/Kenmore       290     52
# Financial District    17      7
# Government Center      3      2
# Harvard Square         4      3
# Hyde Park             32     25
# Jamaica Plain        343    172
# Leather District       9      6
# Mattapan              25     17
# Mission Hill         122     60
# North End            147     55
# Roslindale            56     40
# Roxbury              146     72
# Somerville            21     14
# South Boston         257     93
# South End            329     71
# Theater District      36     14
# West End              81     18
# West Roxbury          42     33
#
#                                                                   top freq
# neighbourhood
# Allston-Brighton    Commonwealth Avenue, Boston, MA 02134, United ...   30
# Back Bay               Beacon Street, Boston, MA 02116, United States   49
# Beacon Hill           Charles Street, Boston, MA 02114, United States   24
# Brookline           Chapel Street, Brookline, MA 02446, United States    2
# Cambridge           Allston Street, Cambridge, MA 02139, United St...    1
# Charlestown         Bunker Hill Street, Boston, MA 02129, United S...    7
# Chestnut Hill                               , MA 02467, United States    2
# Chinatown           Washington Street, Boston, MA 02116, United St...   23
# Dorchester           Crescent Avenue, Boston, MA 02125, United States    9
# Downtown                Union Street, Boston, MA 02108, United States    3
# Downtown Crossing      Winter Street, Boston, MA 02108, United States    6
# East Boston          Maverick Street, Boston, MA 02128, United States   14
# Fenway/Kenmore       Boylston Street, Boston, MA 02215, United States   64
# Financial District  Custom House Tower, 3 McKinley Square, Boston,...    5
# Government Center   Staniford Street, Boston, MA 02114, United States    2
# Harvard Square       Story Street, Cambridge, MA 02138, United States    2
# Hyde Park           Hyde Park Avenue, Boston, MA 02136, United States    4
# Jamaica Plain          Centre Street, Boston, MA 02130, United States   15
# Leather District      Lincoln Street, Boston, MA 02111, United States    4
# Mattapan               Harlem Street, Boston, MA 02121, United States    2
# Mission Hill          Tremont Street, Boston, MA 02120, United States   14
# North End              Prince Street, Boston, MA 02113, United States   11
# Roslindale              Birch Street, Boston, MA 02131, United States    3
# Roxbury             Alvah Kittredge Park, Boston, MA 02119, United...    9
# Somerville          Washington Street, Somerville, MA 02143, Unite...    5
# South Boston        Seaport Boulevard, Boston, MA 02210, United St...   28
# South End            Columbus Avenue, Boston, MA 02116, United States   31
# Theater District     Boylston Street, Boston, MA 02116, United States    8
# West End               Emerson Place, Boston, MA 02114, United States   22
# West Roxbury          Morrell Street, Boston, MA 02132, United States    5

# %%
# Group streets by neighborhood - seattle_listings_df
seattle_listings_df[['neighbourhood','street']].groupby('neighbourhood')['street'].describe()
# Out:
#                           count unique  \
# neighbourhood
# Alki                         35     24
# Arbor Heights                 5      5
# Atlantic                     52     23
# Ballard                     233    109
# Belltown                    221     47
# Bitter Lake                  14     11
# Brighton                      6      4
# Broadview                    16     13
# Broadway                      5      5
# Bryant                       33     16
# Capitol Hill                394     91
# Cedar Park                    9      8
# Central Business District    92     27
# Columbia City                65     42
# Crown Hill                   22     17
# Dunlap                       15      8
# Eastlake                     42     15
# Fairmount Park                1      1
# Fauntleroy                   10     10
# First Hill                  122     33
# Fremont                     160     70
# Gatewood                     19     16
# Genesee                      31     19
# Georgetown                    8      4
# Green Lake                   57     40
# Greenwood                    93     55
# Haller Lake                  17     13
# Harrison/Denny-Blaine        14     12
# High Point                   11      9
# Highland Park                12      9
# ...                         ...    ...
# North Delridge               29     15
# Olympic Hills                15     11
# Phinney Ridge                65     43
# Pike Market                   2      1
# Pike Place Market            44     17
# Pinehurst                     4      3
# Pioneer Square               15      8
# Portage Bay                  19     12
# Queen Anne                  212     89
# Rainier Beach                21     12
# Ravenna                      65     30
# Riverview                     8      7
# Roosevelt                    29     21
# Roxhill                       1      1
# Seaview                       9      9
# Seward Park                  33     21
# South Beacon Hill             2      2
# South Delridge               10      7
# South Lake Union             29     15
# South Park                    4      4
# Stevens                     108     43
# The Junction                 41     28
# University District         122     37
# Victory Heights              14     10
# View Ridge                    6      5
# Wallingford                 167     82
# Wedgewood                    17     12
# Westlake                     15      9
# Windermere                   10      8
# Yesler Terrace               16      9
#
#                                                                          top  \
# neighbourhood
# Alki                       62nd Avenue Southwest, Seattle, WA 98116, Unit...
# Arbor Heights              Southwest 100th Street, Seattle, WA 98146, Uni...
# Atlantic                   Hiawatha Place South, Seattle, WA 98144, Unite...
# Ballard                    Northwest 60th Street, Seattle, WA 98107, Unit...
# Belltown                        1st Avenue, Seattle, WA 98121, United States
# Bitter Lake                Greenwood Avenue North, Seattle, WA 98133, Uni...
# Brighton                   South Othello Street, Seattle, WA 98118, Unite...
# Broadview                  Palatine Avenue North, Seattle, WA 98133, Unit...
# Broadway                   10th Avenue East, Seattle, WA 98102, United St...
# Bryant                     Northeast 55th Street, Seattle, WA 98105, Unit...
# Capitol Hill               12th Avenue East, Seattle, WA 98102, United St...
# Cedar Park                 Sand Point Way Northeast, Seattle, WA 98125, U...
# Central Business District       1st Avenue, Seattle, WA 98101, United States
# Columbia City              South Lucile Street, Seattle, WA 98118, United...
# Crown Hill                   Dibble Ave NW, Seattle, WA 98117, United States
# Dunlap                     44th Avenue South, Seattle, WA 98118, United S...
# Eastlake                   Boylston Avenue East, Seattle, WA 98102, Unite...
# Fairmount Park                    38th Ave, Seattle, WA 98126, United States
# Fauntleroy                 44th Avenue Southwest, Seattle, WA 98136, Unit...
# First Hill                   Hubbell Place, Seattle, WA 98101, United States
# Fremont                    Whitman Avenue North, Seattle, WA 98103, Unite...
# Gatewood                   Southwest Holly Street, Seattle, WA 98136, Uni...
# Genesee                    Southwest Dakota Street, Seattle, WA 98116, Un...
# Georgetown                 Flora Avenue South, Seattle, WA 98108, United ...
# Green Lake                 Latona Avenue Northeast, Seattle, WA 98115, Un...
# Greenwood                  Linden Avenue North, Seattle, WA 98103, United...
# Haller Lake                Densmore Avenue North, Seattle, WA 98133, Unit...
# Harrison/Denny-Blaine      30th Avenue East, Seattle, WA 98112, United St...
# High Point                 Shinkle Place Southwest, Seattle, WA 98106, Un...
# Highland Park              14th Avenue Southwest, Seattle, WA 98106, Unit...
# ...                                                                      ...
# North Delridge             Delridge Way Southwest, Seattle, WA 98106, Uni...
# Olympic Hills              19th Avenue Northeast, Seattle, WA 98125, Unit...
# Phinney Ridge              North 73rd Street, Seattle, WA 98103, United S...
# Pike Market                 Western Avenue, Seattle, WA 98101, United States
# Pike Place Market           Western Avenue, Seattle, WA 98101, United States
# Pinehurst                  Northeast 115th Street, Seattle, WA 98125, Uni...
# Pioneer Square                  Yesler Way, Seattle, WA 98104, United States
# Portage Bay                Fuhrman Avenue East, Seattle, WA 98102, United...
# Queen Anne                 Aurora Avenue North, Seattle, WA 98109, United...
# Rainier Beach              South Redwing Street, Seattle, WA 98118, Unite...
# Ravenna                    27th Avenue Northeast, Seattle, WA 98105, Unit...
# Riverview                  21st Avenue Southwest, Seattle, WA 98106, Unit...
# Roosevelt                  Northeast 61st Street, Seattle, WA 98115, Unit...
# Roxhill                    34th Avenue Southwest, Seattle, WA 98126, Unit...
# Seaview                        Atlas Pl SW, Seattle, WA 98136, United States
# Seward Park                Morgan St. south, Seattle, WA 98118, United St...
# South Beacon Hill          South Portland Street, Seattle, WA 98118, Unit...
# South Delridge             21st Avenue Southwest, Seattle, WA 98106, Unit...
# South Lake Union           Westlake Avenue North, Seattle, WA 98109, Unit...
# South Park                 South Rose Street, Seattle, WA 98108, United S...
# Stevens                    East Highland Drive, Seattle, WA 98112, United...
# The Junction                   36th Ave SW, Seattle, WA 98126, United States
# University District        11th Avenue Northeast, Seattle, WA 98105, Unit...
# Victory Heights            19th Avenue Northeast, Seattle, WA 98115, Unit...
# View Ridge                 Northeast 75th Street, Seattle, WA 98115, Unit...
# Wallingford                Corliss Avenue North, Seattle, WA 98103, Unite...
# Wedgewood                       Ne 89th St, Seattle, WA 98115, United States
# Westlake                   Dexter Avenue North, Seattle, WA 98109, United...
# Windermere                 Stanford Avenue Northeast, Seattle, WA 98105, ...
# Yesler Terrace                 11th Avenue, Seattle, WA 98122, United States
#
#                           freq
# neighbourhood
# Alki                         4
# Arbor Heights                1
# Atlantic                     7
# Ballard                     12
# Belltown                    23
# Bitter Lake                  3
# Brighton                     2
# Broadview                    2
# Broadway                     1
# Bryant                       5
# Capitol Hill                29
# Cedar Park                   2
# Central Business District   24
# Columbia City                5
# Crown Hill                   3
# Dunlap                       4
# Eastlake                     9
# Fairmount Park               1
# Fauntleroy                   1
# First Hill                  28
# Fremont                     18
# Gatewood                     3
# Genesee                      4
# Georgetown                   3
# Green Lake                   4
# Greenwood                    4
# Haller Lake                  3
# Harrison/Denny-Blaine        2
# High Point                   2
# Highland Park                2
# ...                        ...
# North Delridge               8
# Olympic Hills                2
# Phinney Ridge                4
# Pike Market                  2
# Pike Place Market            9
# Pinehurst                    2
# Pioneer Square               5
# Portage Bay                  5
# Queen Anne                   9
# Rainier Beach                3
# Ravenna                      6
# Riverview                    2
# Roosevelt                    3
# Roxhill                      1
# Seaview                      1
# Seward Park                  5
# South Beacon Hill            1
# South Delridge               2
# South Lake Union             9
# South Park                   1
# Stevens                     13
# The Junction                 4
# University District         19
# Victory Heights              2
# View Ridge                   2
# Wallingford                 18
# Wedgewood                    4
# Westlake                     5
# Windermere                   3
# Yesler Terrace               7
#
# [81 rows x 4 columns]

# %%
#Bar plot showing the number of bookings in a neighbourhood in Seattle
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
ax.set_title('Seattle: Number of bookings vs Neighbourhood')
ax.set_xlabel('Neighbourhood')
ax.set_ylabel('Number of bookings')
seattle_merged_df.groupby('neighbourhood')['accommodates'].sum().plot(kind='bar', color='blue', ax=ax)

# %%
#Bar plot showing the number of bookings in a neighbourhood in Boston    
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
ax.set_title('Boston: Number of bookings vs Neighbourhood')
ax.set_xlabel('Neighbourhood')
ax.set_ylabel('Number of bookings')
boston_merged_df.groupby('neighbourhood')['accommodates'].sum().plot(kind='bar', color='blue', ax=ax)

# %%
# Predict price.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

seattle_calander_df = pd.read_csv('./dataset/seattle/calendar.csv', dtype=str)
seattle_listings_df = pd.read_csv('./dataset/seattle/listings.csv', dtype=str)
seattle_reviews_df = pd.read_csv('./dataset/seattle/reviews.csv', dtype=str)

print(seattle_calander_df.shape)
print(seattle_listings_df.shape)
print(seattle_reviews_df.shape)

seattle_calander_df.head()
# Out:
# (1393570, 4)
# (3818, 92)
# (84849, 6)
#   listing_id        date available   price
# 0     241032  2016-01-04         t  $85.00
# 1     241032  2016-01-05         t  $85.00
# 2     241032  2016-01-06         f     NaN
# 3     241032  2016-01-07         f     NaN
# 4     241032  2016-01-08         f     NaN

# %%
seattle_listings_df.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
# 3  A charming apartment that sits atop Queen Anne...                none
# 4  Cozy family craftman house in beautiful neighb...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0                                                NaN  ...                  10
# 1  Queen Anne is a wonderful, truly functional vi...  ...                  10
# 2  Upper Queen Anne is a charming neighborhood fu...  ...                  10
# 3                                                NaN  ...                 NaN
# 4  We are in the beautiful neighborhood of Queen ...  ...                   9
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN         WASHINGTON                f
# 1                f     NaN         WASHINGTON                f
# 2                f     NaN         WASHINGTON                f
# 3                f     NaN         WASHINGTON                f
# 4                f     NaN         WASHINGTON                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1              strict                             t
# 2              strict                             f
# 3            flexible                             f
# 4              strict                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              2
# 1                                t                              6
# 2                                f                              2
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              4.07
# 1              1.48
# 2              1.15
# 3               NaN
# 4              0.89
#
# [5 rows x 92 columns]

# %%
seattle_reviews_df.head()
# Out:
#   listing_id        id        date reviewer_id reviewer_name  \
# 0    7202016  38917982  2015-07-19    28943674        Bianca
# 1    7202016  39087409  2015-07-20    32440555         Frank
# 2    7202016  39820030  2015-07-26    37722850           Ian
# 3    7202016  40813543  2015-08-02    33671805        George
# 4    7202016  41986501  2015-08-10    34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
boston_calander_df = pd.read_csv('./dataset/boston/calendar.csv', dtype=str)
boston_listings_df = pd.read_csv('./dataset/boston/listings.csv', dtype=str)
boston_reviews_df = pd.read_csv('./dataset/boston/reviews.csv', dtype=str)

print(boston_calander_df.shape)
print(boston_listings_df.shape)
print(boston_reviews_df.shape)
boston_calander_df.head()
# Out:
# (1308890, 4)
# (3585, 95)
# (68275, 6)
#   listing_id        date available price
# 0   12147973  2017-09-05         f   NaN
# 1   12147973  2017-09-04         f   NaN
# 2   12147973  2017-09-03         f   NaN
# 3   12147973  2017-09-02         f   NaN
# 4   12147973  2017-09-01         f   NaN

# %%
boston_listings_df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
# 1  The room is in Roslindale, a diverse and prima...  ...                   9
# 2  The LOCATION: Roslindale is a safe and diverse...  ...                  10
# 3  Roslindale is a lovely little neighborhood loc...  ...                  10
# 4  I love the proximity to downtown, the neighbor...  ...                  10
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                t
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0               NaN
# 1              1.30
# 2              0.47
# 3                 1
# 4              2.25
#
# [5 rows x 95 columns]

# %%
boston_reviews_df.head()
# Out:
#   listing_id       id        date reviewer_id reviewer_name  \
# 0    1178162  4724140  2013-05-21     4298113       Olivier
# 1    1178162  4869189  2013-05-29     6452964     Charlotte
# 2    1178162  5003196  2013-06-06     6449554     Sebastian
# 3    1178162  5150351  2013-06-15     2215611        Marine
# 4    1178162  5171140  2013-06-16     6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
    # Questions to ask:
    # * Average visitors to Seattle/Boston over time?
    #  - date, accommodates (columns)
    # * Which areas are more crowded, which areas are more preferred by people?
    #  - neighbourhood, zipcode (columns)
    # * Busiest time to visit Seattle/Boston?
    #  - last_scraped, accommodates (columns)
    # * Compare rates between the two cities over time.
    #  - price, date, weekly_price, monthly_price (columns) from calendar.csv
    # * Predict price.
    #  - property_type, room_type, neighbourhood, zipcode, accommodates, 
    #  cancellation_policy (columns or more)

# %%
def clean_data():
    
    #filling missing values for the field 'price' in dataframes 'seattle_calander_df' and 'boston_calander_df'
    seattle_calander_df['price'].fillna(method='ffill', inplace=True)
    boston_calander_df['price'].fillna(method='bfill', inplace=True)
    boston_calander_df['price'].fillna(method='ffill', inplace=True)
    
    #Removing '$' and ',' symbol from price in dataframes 'seattle_calander_df' and 'boston_calander_df'
    seattle_calander_df['price'] = seattle_calander_df['price'].str.replace('$', '')
    seattle_calander_df['price'] = seattle_calander_df['price'].str.replace(',', '')
    boston_calander_df['price'] = boston_calander_df['price'].str.replace('$', '')
    boston_calander_df['price'] = boston_calander_df['price'].str.replace(',', '')
    
    #Removing '$' and ',' symbol from price in dataframes'seattle_listings_df' and 'boston_listings_df'
    seattle_listings_df['price'] = seattle_listings_df['price'].str.replace('$', '')
    seattle_listings_df['price'] = seattle_listings_df['price'].str.replace(',', '')
    boston_listings_df['price'] = boston_listings_df['price'].str.replace('$', '')
    boston_listings_df['price'] = boston_listings_df['price'].str.replace(',', '')
    
    #convert 'price' column in dataframes 'seattle_calander_df', 'seattle_calander_df', 'boston_calander_df' and 'boston_calander_df' to float type  
    seattle_calander_df["price"] = pd.to_numeric(seattle_calander_df["price"])
    seattle_listings_df["price"] = pd.to_numeric(seattle_listings_df["price"])
    boston_calander_df["price"] = pd.to_numeric(boston_calander_df["price"])
    boston_listings_df["price"] = pd.to_numeric(boston_listings_df["price"])
    
    #Renaming column 'id' to 'listing_id' in dataframes 'seattle_listings_df'  and 'boston_calander_df' 
    seattle_listings_df.rename(columns={"id": "listing_id"}, inplace=True)
    boston_listings_df.rename(columns={"id": "listing_id"}, inplace=True)
    
    
clean_data()

# %%
#Compare rates between the two cities over time.
#-----------------------------------------------

#check if there are any NaN values in the column 'price' in dataframes 'seattle_calander_df' and 'boston_calander_df'
seattle_calander_df[seattle_calander_df['price'].isna() == True]
boston_calander_df[boston_calander_df['price'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [listing_id, date, available, price]
# Index: []

# %%
#adding columns for month and year in dataframes
func_month = lambda x: x.split('-')[1] 
func_year = lambda x: x.split('-')[0] 

seattle_calander_df['month'] = pd.to_numeric(seattle_calander_df['date'].apply(func_month))
seattle_calander_df['year'] = pd.to_numeric(seattle_calander_df['date'].apply(func_year))

boston_calander_df['month'] = pd.to_numeric(boston_calander_df['date'].apply(func_month))
boston_calander_df['year'] = pd.to_numeric(boston_calander_df['date'].apply(func_year))

# %%
boston_calander_df.head()
# Out:
#   listing_id        date available  price  month  year
# 0   12147973  2017-09-05         f   65.0      9  2017
# 1   12147973  2017-09-04         f   65.0      9  2017
# 2   12147973  2017-09-03         f   65.0      9  2017
# 3   12147973  2017-09-02         f   65.0      9  2017
# 4   12147973  2017-09-01         f   65.0      9  2017

# %%
#Selecting only the year 2016
seattle_calander_df = seattle_calander_df[seattle_calander_df['year'] == 2016]
boston_calander_df = boston_calander_df[boston_calander_df['year'] == 2017]

# %%
boston_calander_df.head()
# Out:
#   listing_id        date available  price  month  year
# 0   12147973  2017-09-05         f   65.0      9  2017
# 1   12147973  2017-09-04         f   65.0      9  2017
# 2   12147973  2017-09-03         f   65.0      9  2017
# 3   12147973  2017-09-02         f   65.0      9  2017
# 4   12147973  2017-09-01         f   65.0      9  2017

# %%
#Line plot for the average price for a month over a year for Seattle
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111)
ax.set_xlabel('Month')
ax.set_ylabel('Price')

seattle_calander_df.groupby('month')['price'].mean().plot(kind='line', color='blue', ax=ax)

# %%
#Line plot for the average price for a month over a year for Boston
fig1 = plt.figure(figsize=(10,5))
ax1 = fig1.add_subplot(111)
ax1.set_xlabel('Month')
ax1.set_ylabel('Price')
boston_calander_df.groupby('month')['price'].mean().plot(kind='line', color='red', ax=ax1)

# %%
# Average visitors to Seattle/Boston over time?

#Merge dataframes 'seattle_calander_df' and 'seattle_listings_df'
merged_df = pd.merge(seattle_calander_df, seattle_listings_df, on=['listing_id', 'price'], how='left')

# %%
merged_df
# Out:
#         listing_id        date available  price  month  year  \
# 0           241032  2016-01-04         t   85.0      1  2016
# 1           241032  2016-01-05         t   85.0      1  2016
# 2           241032  2016-01-06         f   85.0      1  2016
# 3           241032  2016-01-07         f   85.0      1  2016
# 4           241032  2016-01-08         f   85.0      1  2016
# 5           241032  2016-01-09         f   85.0      1  2016
# 6           241032  2016-01-10         f   85.0      1  2016
# 7           241032  2016-01-11         f   85.0      1  2016
# 8           241032  2016-01-12         f   85.0      1  2016
# 9           241032  2016-01-13         t   85.0      1  2016
# 10          241032  2016-01-14         t   85.0      1  2016
# 11          241032  2016-01-15         f   85.0      1  2016
# 12          241032  2016-01-16         f   85.0      1  2016
# 13          241032  2016-01-17         f   85.0      1  2016
# 14          241032  2016-01-18         t   85.0      1  2016
# 15          241032  2016-01-19         t   85.0      1  2016
# 16          241032  2016-01-20         t   85.0      1  2016
# 17          241032  2016-01-21         f   85.0      1  2016
# 18          241032  2016-01-22         f   85.0      1  2016
# 19          241032  2016-01-23         f   85.0      1  2016
# 20          241032  2016-01-24         t   85.0      1  2016
# 21          241032  2016-01-25         t   85.0      1  2016
# 22          241032  2016-01-26         t   85.0      1  2016
# 23          241032  2016-01-27         t   85.0      1  2016
# 24          241032  2016-01-28         t   85.0      1  2016
# 25          241032  2016-01-29         f   85.0      1  2016
# 26          241032  2016-01-30         f   85.0      1  2016
# 27          241032  2016-01-31         f   85.0      1  2016
# 28          241032  2016-02-01         t   85.0      2  2016
# 29          241032  2016-02-02         t   85.0      2  2016
# ...            ...         ...       ...    ...    ...   ...
# 1385904   10208623  2016-12-02         f   87.0     12  2016
# 1385905   10208623  2016-12-03         f   87.0     12  2016
# 1385906   10208623  2016-12-04         f   87.0     12  2016
# 1385907   10208623  2016-12-05         f   87.0     12  2016
# 1385908   10208623  2016-12-06         f   87.0     12  2016
# 1385909   10208623  2016-12-07         f   87.0     12  2016
# 1385910   10208623  2016-12-08         f   87.0     12  2016
# 1385911   10208623  2016-12-09         f   87.0     12  2016
# 1385912   10208623  2016-12-10         f   87.0     12  2016
# 1385913   10208623  2016-12-11         f   87.0     12  2016
# 1385914   10208623  2016-12-12         f   87.0     12  2016
# 1385915   10208623  2016-12-13         f   87.0     12  2016
# 1385916   10208623  2016-12-14         f   87.0     12  2016
# 1385917   10208623  2016-12-15         f   87.0     12  2016
# 1385918   10208623  2016-12-16         f   87.0     12  2016
# 1385919   10208623  2016-12-17         f   87.0     12  2016
# 1385920   10208623  2016-12-18         f   87.0     12  2016
# 1385921   10208623  2016-12-19         f   87.0     12  2016
# 1385922   10208623  2016-12-20         f   87.0     12  2016
# 1385923   10208623  2016-12-21         f   87.0     12  2016
# 1385924   10208623  2016-12-22         f   87.0     12  2016
# 1385925   10208623  2016-12-23         f   87.0     12  2016
# 1385926   10208623  2016-12-24         f   87.0     12  2016
# 1385927   10208623  2016-12-25         f   87.0     12  2016
# 1385928   10208623  2016-12-26         f   87.0     12  2016
# 1385929   10208623  2016-12-27         f   87.0     12  2016
# 1385930   10208623  2016-12-28         f   87.0     12  2016
# 1385931   10208623  2016-12-29         f   87.0     12  2016
# 1385932   10208623  2016-12-30         f   87.0     12  2016
# 1385933   10208623  2016-12-31         f   87.0     12  2016
#
#                                    listing_url       scrape_id last_scraped  \
# 0          https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1          https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 2          https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 3          https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 4          https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 5          https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 6          https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 7          https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 8          https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 9          https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 10         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 11         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 12         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 13         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 14         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 15         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 16         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 17         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 18         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 19         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 20         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 21         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 22         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 23         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 24         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 25         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 26         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 27         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 28         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 29         https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# ...                                        ...             ...          ...
# 1385904  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385905  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385906  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385907  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385908  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385909  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385910  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385911  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385912  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385913  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385914  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385915  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385916  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385917  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385918  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385919  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385920  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385921  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385922  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385923  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385924  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385925  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385926  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385927  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385928  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385929  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385930  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385931  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385932  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
# 1385933  https://www.airbnb.com/rooms/10208623  20160104002432   2016-01-04
#
#                                  name  ... review_scores_value  \
# 0        Stylish Queen Anne Apartment  ...                  10
# 1        Stylish Queen Anne Apartment  ...                  10
# 2        Stylish Queen Anne Apartment  ...                  10
# 3        Stylish Queen Anne Apartment  ...                  10
# 4        Stylish Queen Anne Apartment  ...                  10
# 5        Stylish Queen Anne Apartment  ...                  10
# 6        Stylish Queen Anne Apartment  ...                  10
# 7        Stylish Queen Anne Apartment  ...                  10
# 8        Stylish Queen Anne Apartment  ...                  10
# 9        Stylish Queen Anne Apartment  ...                  10
# 10       Stylish Queen Anne Apartment  ...                  10
# 11       Stylish Queen Anne Apartment  ...                  10
# 12       Stylish Queen Anne Apartment  ...                  10
# 13       Stylish Queen Anne Apartment  ...                  10
# 14       Stylish Queen Anne Apartment  ...                  10
# 15       Stylish Queen Anne Apartment  ...                  10
# 16       Stylish Queen Anne Apartment  ...                  10
# 17       Stylish Queen Anne Apartment  ...                  10
# 18       Stylish Queen Anne Apartment  ...                  10
# 19       Stylish Queen Anne Apartment  ...                  10
# 20       Stylish Queen Anne Apartment  ...                  10
# 21       Stylish Queen Anne Apartment  ...                  10
# 22       Stylish Queen Anne Apartment  ...                  10
# 23       Stylish Queen Anne Apartment  ...                  10
# 24       Stylish Queen Anne Apartment  ...                  10
# 25       Stylish Queen Anne Apartment  ...                  10
# 26       Stylish Queen Anne Apartment  ...                  10
# 27       Stylish Queen Anne Apartment  ...                  10
# 28       Stylish Queen Anne Apartment  ...                  10
# 29       Stylish Queen Anne Apartment  ...                  10
# ...                               ...  ...                 ...
# 1385904     Large Lakefront Apartment  ...                 NaN
# 1385905     Large Lakefront Apartment  ...                 NaN
# 1385906     Large Lakefront Apartment  ...                 NaN
# 1385907     Large Lakefront Apartment  ...                 NaN
# 1385908     Large Lakefront Apartment  ...                 NaN
# 1385909     Large Lakefront Apartment  ...                 NaN
# 1385910     Large Lakefront Apartment  ...                 NaN
# 1385911     Large Lakefront Apartment  ...                 NaN
# 1385912     Large Lakefront Apartment  ...                 NaN
# 1385913     Large Lakefront Apartment  ...                 NaN
# 1385914     Large Lakefront Apartment  ...                 NaN
# 1385915     Large Lakefront Apartment  ...                 NaN
# 1385916     Large Lakefront Apartment  ...                 NaN
# 1385917     Large Lakefront Apartment  ...                 NaN
# 1385918     Large Lakefront Apartment  ...                 NaN
# 1385919     Large Lakefront Apartment  ...                 NaN
# 1385920     Large Lakefront Apartment  ...                 NaN
# 1385921     Large Lakefront Apartment  ...                 NaN
# 1385922     Large Lakefront Apartment  ...                 NaN
# 1385923     Large Lakefront Apartment  ...                 NaN
# 1385924     Large Lakefront Apartment  ...                 NaN
# 1385925     Large Lakefront Apartment  ...                 NaN
# 1385926     Large Lakefront Apartment  ...                 NaN
# 1385927     Large Lakefront Apartment  ...                 NaN
# 1385928     Large Lakefront Apartment  ...                 NaN
# 1385929     Large Lakefront Apartment  ...                 NaN
# 1385930     Large Lakefront Apartment  ...                 NaN
# 1385931     Large Lakefront Apartment  ...                 NaN
# 1385932     Large Lakefront Apartment  ...                 NaN
# 1385933     Large Lakefront Apartment  ...                 NaN
#
#         requires_license license jurisdiction_names instant_bookable  \
# 0                      f     NaN         WASHINGTON                f
# 1                      f     NaN         WASHINGTON                f
# 2                      f     NaN         WASHINGTON                f
# 3                      f     NaN         WASHINGTON                f
# 4                      f     NaN         WASHINGTON                f
# 5                      f     NaN         WASHINGTON                f
# 6                      f     NaN         WASHINGTON                f
# 7                      f     NaN         WASHINGTON                f
# 8                      f     NaN         WASHINGTON                f
# 9                      f     NaN         WASHINGTON                f
# 10                     f     NaN         WASHINGTON                f
# 11                     f     NaN         WASHINGTON                f
# 12                     f     NaN         WASHINGTON                f
# 13                     f     NaN         WASHINGTON                f
# 14                     f     NaN         WASHINGTON                f
# 15                     f     NaN         WASHINGTON                f
# 16                     f     NaN         WASHINGTON                f
# 17                     f     NaN         WASHINGTON                f
# 18                     f     NaN         WASHINGTON                f
# 19                     f     NaN         WASHINGTON                f
# 20                     f     NaN         WASHINGTON                f
# 21                     f     NaN         WASHINGTON                f
# 22                     f     NaN         WASHINGTON                f
# 23                     f     NaN         WASHINGTON                f
# 24                     f     NaN         WASHINGTON                f
# 25                     f     NaN         WASHINGTON                f
# 26                     f     NaN         WASHINGTON                f
# 27                     f     NaN         WASHINGTON                f
# 28                     f     NaN         WASHINGTON                f
# 29                     f     NaN         WASHINGTON                f
# ...                  ...     ...                ...              ...
# 1385904                f     NaN         WASHINGTON                f
# 1385905                f     NaN         WASHINGTON                f
# 1385906                f     NaN         WASHINGTON                f
# 1385907                f     NaN         WASHINGTON                f
# 1385908                f     NaN         WASHINGTON                f
# 1385909                f     NaN         WASHINGTON                f
# 1385910                f     NaN         WASHINGTON                f
# 1385911                f     NaN         WASHINGTON                f
# 1385912                f     NaN         WASHINGTON                f
# 1385913                f     NaN         WASHINGTON                f
# 1385914                f     NaN         WASHINGTON                f
# 1385915                f     NaN         WASHINGTON                f
# 1385916                f     NaN         WASHINGTON                f
# 1385917                f     NaN         WASHINGTON                f
# 1385918                f     NaN         WASHINGTON                f
# 1385919                f     NaN         WASHINGTON                f
# 1385920                f     NaN         WASHINGTON                f
# 1385921                f     NaN         WASHINGTON                f
# 1385922                f     NaN         WASHINGTON                f
# 1385923                f     NaN         WASHINGTON                f
# 1385924                f     NaN         WASHINGTON                f
# 1385925                f     NaN         WASHINGTON                f
# 1385926                f     NaN         WASHINGTON                f
# 1385927                f     NaN         WASHINGTON                f
# 1385928                f     NaN         WASHINGTON                f
# 1385929                f     NaN         WASHINGTON                f
# 1385930                f     NaN         WASHINGTON                f
# 1385931                f     NaN         WASHINGTON                f
# 1385932                f     NaN         WASHINGTON                f
# 1385933                f     NaN         WASHINGTON                f
#
#         cancellation_policy require_guest_profile_picture  \
# 0                  moderate                             f
# 1                  moderate                             f
# 2                  moderate                             f
# 3                  moderate                             f
# 4                  moderate                             f
# 5                  moderate                             f
# 6                  moderate                             f
# 7                  moderate                             f
# 8                  moderate                             f
# 9                  moderate                             f
# 10                 moderate                             f
# 11                 moderate                             f
# 12                 moderate                             f
# 13                 moderate                             f
# 14                 moderate                             f
# 15                 moderate                             f
# 16                 moderate                             f
# 17                 moderate                             f
# 18                 moderate                             f
# 19                 moderate                             f
# 20                 moderate                             f
# 21                 moderate                             f
# 22                 moderate                             f
# 23                 moderate                             f
# 24                 moderate                             f
# 25                 moderate                             f
# 26                 moderate                             f
# 27                 moderate                             f
# 28                 moderate                             f
# 29                 moderate                             f
# ...                     ...                           ...
# 1385904            flexible                             f
# 1385905            flexible                             f
# 1385906            flexible                             f
# 1385907            flexible                             f
# 1385908            flexible                             f
# 1385909            flexible                             f
# 1385910            flexible                             f
# 1385911            flexible                             f
# 1385912            flexible                             f
# 1385913            flexible                             f
# 1385914            flexible                             f
# 1385915            flexible                             f
# 1385916            flexible                             f
# 1385917            flexible                             f
# 1385918            flexible                             f
# 1385919            flexible                             f
# 1385920            flexible                             f
# 1385921            flexible                             f
# 1385922            flexible                             f
# 1385923            flexible                             f
# 1385924            flexible                             f
# 1385925            flexible                             f
# 1385926            flexible                             f
# 1385927            flexible                             f
# 1385928            flexible                             f
# 1385929            flexible                             f
# 1385930            flexible                             f
# 1385931            flexible                             f
# 1385932            flexible                             f
# 1385933            flexible                             f
#
#         require_guest_phone_verification calculated_host_listings_count  \
# 0                                      f                              2
# 1                                      f                              2
# 2                                      f                              2
# 3                                      f                              2
# 4                                      f                              2
# 5                                      f                              2
# 6                                      f                              2
# 7                                      f                              2
# 8                                      f                              2
# 9                                      f                              2
# 10                                     f                              2
# 11                                     f                              2
# 12                                     f                              2
# 13                                     f                              2
# 14                                     f                              2
# 15                                     f                              2
# 16                                     f                              2
# 17                                     f                              2
# 18                                     f                              2
# 19                                     f                              2
# 20                                     f                              2
# 21                                     f                              2
# 22                                     f                              2
# 23                                     f                              2
# 24                                     f                              2
# 25                                     f                              2
# 26                                     f                              2
# 27                                     f                              2
# 28                                     f                              2
# 29                                     f                              2
# ...                                  ...                            ...
# 1385904                                f                              1
# 1385905                                f                              1
# 1385906                                f                              1
# 1385907                                f                              1
# 1385908                                f                              1
# 1385909                                f                              1
# 1385910                                f                              1
# 1385911                                f                              1
# 1385912                                f                              1
# 1385913                                f                              1
# 1385914                                f                              1
# 1385915                                f                              1
# 1385916                                f                              1
# 1385917                                f                              1
# 1385918                                f                              1
# 1385919                                f                              1
# 1385920                                f                              1
# 1385921                                f                              1
# 1385922                                f                              1
# 1385923                                f                              1
# 1385924                                f                              1
# 1385925                                f                              1
# 1385926                                f                              1
# 1385927                                f                              1
# 1385928                                f                              1
# 1385929                                f                              1
# 1385930                                f                              1
# 1385931                                f                              1
# 1385932                                f                              1
# 1385933                                f                              1
#
#         reviews_per_month
# 0                    4.07
# 1                    4.07
# 2                    4.07
# 3                    4.07
# 4                    4.07
# 5                    4.07
# 6                    4.07
# 7                    4.07
# 8                    4.07
# 9                    4.07
# 10                   4.07
# 11                   4.07
# 12                   4.07
# 13                   4.07
# 14                   4.07
# 15                   4.07
# 16                   4.07
# 17                   4.07
# 18                   4.07
# 19                   4.07
# 20                   4.07
# 21                   4.07
# 22                   4.07
# 23                   4.07
# 24                   4.07
# 25                   4.07
# 26                   4.07
# 27                   4.07
# 28                   4.07
# 29                   4.07
# ...                   ...
# 1385904               NaN
# 1385905               NaN
# 1385906               NaN
# 1385907               NaN
# 1385908               NaN
# 1385909               NaN
# 1385910               NaN
# 1385911               NaN
# 1385912               NaN
# 1385913               NaN
# 1385914               NaN
# 1385915               NaN
# 1385916               NaN
# 1385917               NaN
# 1385918               NaN
# 1385919               NaN
# 1385920               NaN
# 1385921               NaN
# 1385922               NaN
# 1385923               NaN
# 1385924               NaN
# 1385925               NaN
# 1385926               NaN
# 1385927               NaN
# 1385928               NaN
# 1385929               NaN
# 1385930               NaN
# 1385931               NaN
# 1385932               NaN
# 1385933               NaN
#
# [1385934 rows x 96 columns]
